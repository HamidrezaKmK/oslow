# %%
import pandas as pd
# Out:
# /tmp/ipykernel_10841/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("pnl_sinusoid_gumbel.csv")
df
# Out:
#                                    Name  data.graph_generator.num_nodes  \
# 0       12676754_ghostwritten_oversmall                               6
# 1         12676750_counterarch_repermit                               4
# 2              12676749_rerub_chitinous                               6
# 3      12676753_outclasses_elaeodendron                               5
# 4            12676745_abyssinian_yagers                               6
# 5    12676747_oilstones_oversqueamishly                               5
# 6   12676752_preinfluence_unindemnified                               5
# 7        12676755_buncombes_gastrotrich                               3
# 8             12676748_cachespell_rasps                               4
# 9    12676746_microsaurian_lootiewallah                               4
# 10         12676751_accourt_ingeniosity                               3
# 11       12676738_mechanically_undeftly                               3
#
# ...

# %%
df["evaluation/best_backward_penalty"].mean(), df[
    "evaluation/best_backward_penalty"
].std()
# Out:
# (0.3729166666666666, 0.3452258263979119)
